# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
import math
from scipy.stats import boxcox, mannwhitneyu
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, PowerTransformer, QuantileTransformer
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import f_classif
import scipy.stats as stats
import statistics
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer

# %%
x_test = pd.read_csv('x_test.csv', delimiter=',')
x_train = pd.read_csv('x_train.csv', delimiter=',')
y_test = pd.read_csv('y_test.csv', delimiter=',')
y_train = pd.read_csv('y_train.csv', delimiter=',')
# observation = pd.read_csv('../../observation.csv', delimiter='\t')

# %%
# train_data, test_data = train_test_split(
#     observation,
#     test_size=0.25,
#     random_state=42
# )

# target_column = 'oximetry'

# x_train = train_data.drop(columns=[target_column])
# y_train = train_data[target_column]
# x_test = test_data.drop(columns=[target_column])
# y_test = test_data[target_column]
y_train = y_train.values
y_test = y_test.values
x_train = x_train.values
x_test = x_test.values

# %%
x_train
# Out:
# array([[ 0.44257304,  0.4562148 ,  0.50761327, ...,  0.78822813,
#         -1.92576546,  2.12390495],
#        [ 0.36073269,  0.64401201,  0.44434423, ...,  0.32753305,
#          0.54126375, -1.11877009],
#        [ 0.37561029,  0.75102677,  0.50271997, ...,  0.18704173,
#          0.74765463,  1.01807214],
#        ...,
#        [ 0.48574036,  0.83750257,  0.50758185, ...,  0.31141528,
#          0.25045496,  1.28530485],
#        [ 0.5975248 ,  0.39988548,  0.48044926, ...,  0.09859388,
#          1.03534586, -0.24414921],
#        [ 0.58223391,  0.53165138,  0.26058361, ...,  0.66667937,
#         -0.38474984,  0.84139111]], shape=(8765, 22))

# %%
y_train
# Out:
# array([[1.],
#        [0.],
#        [0.],
#        ...,
#        [1.],
#        [1.],
#        [1.]], shape=(8765, 1))

# %%
x_train.shape
# Out:
# (8765, 22)

# %%
# def trashhold(col):   
#     arr = np.array([])
#     sorted_col = np.sort(col)
#     x=0
#     while x<col.shape[0]:
#         z = np.mean(sorted_col[x:min(x+50,col.shape[0])])
#         arr = np.append(arr, z)
#         x+=50
#     return arr

# %%
class Node:
    def __init__(self, final_value=None, value=None, classname=None,
                 datasetx=None, datasety=None, left_node=None, right_node=None):
        self.value = value          # threshold
        self.final_value = final_value  # predicted class in leaf
        self.classname = classname      # feature index
        self.datasetx = datasetx
        self.datasety = datasety
        self.left_node = left_node
        self.right_node = right_node


def init_tree(x_t, y_t):
    y_t = y_t.flatten()
    return Node(datasetx=x_t, datasety=y_t)


def get_majority(y):
    return 1 if y.sum() >= len(y) / 2 else 0


def entropy(pos, neg):
    total = pos + neg
    if total == 0:
        return 0.0

    p1 = pos / total
    p0 = neg / total

    e = 0
    if p1 > 0:
        e -= p1 * np.log2(p1)
    if p0 > 0:
        e -= p0 * np.log2(p0)

    return e


def information_gain(parent_pos, parent_neg, left_pos, left_neg, right_pos, right_neg):
    n = parent_pos + parent_neg
    nl = left_pos + left_neg
    nr = right_pos + right_neg

    H_parent = entropy(parent_pos, parent_neg)
    H_left = entropy(left_pos, left_neg)
    H_right = entropy(right_pos, right_neg)

    return H_parent - (nl / n) * H_left - (nr / n) * H_right


def possible_thresholds(col):
    uniq = np.unique(col)
    if len(uniq) <= 1:
        return []

    thr = (uniq[:-1] + uniq[1:]) / 2
    return thr


def model_run(node, epoch, max_depth=5):

    if epoch >= max_depth or node.datasetx.shape[0] == 0:
        node.final_value = get_majority(node.datasety)
        return node

    X = node.datasetx
    y = node.datasety.flatten()

    parent_pos = y.sum()
    parent_neg = len(y) - parent_pos

    n_features = X.shape[1]

    best_ig = -1
    best_feature = None
    best_threshold = None
    best_left_x = None
    best_left_y = None
    best_right_x = None
    best_right_y = None

    for f in range(n_features):
        col = X[:, f]
        thresholds = possible_thresholds(col)

        for thr in thresholds:
            left_mask = col <= thr
            right_mask = ~left_mask

            yl = y[left_mask]
            yr = y[right_mask]

            if len(yl) == 0 or len(yr) == 0:
                continue

            pos_l = yl.sum()
            neg_l = len(yl) - pos_l

            pos_r = yr.sum()
            neg_r = len(yr) - pos_r

            ig = information_gain(parent_pos, parent_neg, pos_l, neg_l, pos_r, neg_r)

            if ig > best_ig:
                best_ig = ig
                best_feature = f
                best_threshold = thr
                best_left_x = X[left_mask]
                best_left_y = yl
                best_right_x = X[right_mask]
                best_right_y = yr

    if best_ig <= 1e-12 or best_feature is None:
        node.final_value = get_majority(y)
        return node

    node.value = best_threshold
    node.classname = best_feature

    left_node = Node(datasetx=best_left_x, datasety=best_left_y)
    right_node = Node(datasetx=best_right_x, datasety=best_right_y)

    node.left_node = model_run(left_node, epoch + 1, max_depth)
    node.right_node = model_run(right_node, epoch + 1, max_depth)

    return node

# %%
def predict_one(node, x):
    while True:
        if node.final_value is not None:
            return node.final_value

        f = node.classname
        thr = node.value

        if x[f] <= thr:
            node = node.left_node
        else:
            node = node.right_node


def predict(node, X):
    return np.array([predict_one(node, row) for row in X])

# %%
inode = init_tree(x_train, y_train)
tree = model_run(inode, 0)

y_pred = predict(tree, x_train)
acc = accuracy(y_train, y_pred)

print("Accuracy:", acc)
# Out:
# Accuracy: 0.8203402918767893

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score

rf = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    bootstrap=True,
    n_jobs=-1
)

rf.fit(x_train, y_train)

y_pred = rf.predict(x_test)

acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)

print("Random Forest Accuracy:", acc)
print("Precision:", prec)
print("Recall:", rec)
# Out:
# C:\Users\nikio\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Random Forest Accuracy: 0.8966461327857632
# Precision: 0.9047619047619048
# Recall: 0.9186320754716981
